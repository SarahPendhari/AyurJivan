# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import pandas as pd

# %%
df=pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/questions1.csv")

# %%
df
# Out:
#      questions   Unnamed: 1                         Unnamed: 2  \
# 0    Body Size  Body Weight                               Eyes
# 1         Slim          Low                              Small
# 2       Medium       Medium                              Sharp
# 3        Large   Overweight                                Big
# 4         Slim       Medium                              Small
# ..         ...          ...                                ...
# 125       Slim          Low                 Small, Sunken, Dry
# 126       Slim          Low  Sharp, Bright, Sensitive to Light
# 127       Slim          Low                 Small, Sunken, Dry
# 128       Slim          Low  Sharp, Bright, Sensitive to Light
# 129       Slim          Low                 Small, Sunken, Dry
#
#                      Unnamed: 3     Unnamed: 4  \
# 0                          Nose           Lips
# 1                        Uneven            Dry
# 2                  Long-pointed       Inflamed
# 3                 Short rounded         Smooth
# 4                  Long-pointed       Inflamed
# ..                          ...            ...
# 125  Long Pointed, Red Nose-Tip  Red, Inflamed
# 126  Short Rounded, Button Nose   Dry, Cracked
# 127  Long Pointed, Red Nose-Tip  Red, Inflamed
# 128  Short Rounded, Button Nose   Dry, Cracked
# 129  Long Pointed, Red Nose-Tip  Red, Inflamed
#
#                            Unnamed: 5              Unnamed: 6  \
# 0                               Teeth                    Skin
# 1                                Thin                     Dry
# 2                              Medium                  Smooth
# 3                             Healthy                    Oily
# 4                              Medium                     Dry
# ..                                ...                     ...
# 125  Stick Out, Big, Roomy, Thin Gums  Thin, Dry, Cold, Rough
# 126         Medium, Soft, Tender Gums      Smooth, Oily, Warm
# 127  Stick Out, Big, Roomy, Thin Gums  Thin, Dry, Cold, Rough
# 128         Medium, Soft, Tender Gums      Smooth, Oily, Warm
# 129  Stick Out, Big, Roomy, Thin Gums  Thin, Dry, Cold, Rough
#
#                  Unnamed: 7          Unnamed: 8              Unnamed: 9  \
# 0                      Hair            Appetite               Digestion
# 1           Dry and brittle           Irregular     Irregular forms gas
# 2         Straight and oily              Strong    Quick causes burning
# 3           Thick and curly     Slow but steady  Prolonged forms mucous
# 4         Straight and oily              Strong    Quick causes burning
# ..                      ...                 ...                     ...
# 125        Dry, Brown/Black   Irregular, Scanty      Slow, Forms Mucous
# 126  Straight, Oily, Blonde  Strong, Unbearable   Quick, Causes Burning
# 127        Dry, Brown/Black   Irregular, Scanty      Slow, Forms Mucous
# 128  Straight, Oily, Blonde  Strong, Unbearable   Quick, Causes Burning
# 129        Dry, Brown/Black   Irregular, Scanty      Slow, Forms Mucous
#
#     Unnamed: 10                      Unnamed: 11   Unnamed: 12  \
# 0        Thirst                         Emotions          Mind
# 1    Changeable                          Anxiety      Restless
# 2       Surplus                            Anger     Impatient
# 3        Sparse                             Calm        Calmer
# 4       Surplus                          Anxiety     Impatient
# ..          ...                              ...           ...
# 125      Sparse            Anger, Hate, Jealousy     Impatient
# 126  Changeable            Anger, Hate, Jealousy  Restlessness
# 127      Sparse  Calmness, Patience, Contentment  Restlessness
# 128  Changeable       Anxiety, Fear, Uncertainty     Impatient
# 129      Sparse  Calmness, Patience, Contentment  Restlessness
#
#                    Unnamed: 13                Unnamed: 14         Unnamed: 15  \
# 0                    Intellect                     Speech               Voice
# 1    Quick but faulty response        Rapid and talkative     Weak and hoarse
# 2            Accurate response            Clear and sharp         Strong tone
# 3               Slow and exact             Quiet and slow  Deep and good tone
# 4            Accurate response        Rapid and talkative     Weak and hoarse
# ..                         ...                        ...                 ...
# 125                Slow, Exact    Clear, Slow, Monotonous     Deep, Good Tone
# 126          Accurate Response  Clear, Sharp, Penetrating         Strong Tone
# 127  Quick but Faulty Response    Quiet, Slow, Monotonous        Weak, Hoarse
# 128  Quick but Faulty Response  Rapid, Unclear, Talkative         Strong Tone
# 129          Accurate Response  Clear, Sharp, Penetrating     Deep, Good Tone
#
#         Unnamed: 16       Unnamed: 17      Unnamed: 18   Unnamed: 19
# 0            Dreams  Season Preferred  Predicted Dosha  Actual Dosha
# 1       Imaginative            Summer             Vata           NaN
# 2         Realistic            Winter            Pitta           NaN
# 3    Lack of dreams            Summer            Kapha           NaN
# 4       Imaginative             Rainy             Vata           NaN
# ..              ...               ...              ...           ...
# 125       Realistic            Winter             Vata           NaN
# 126  Lack of dreams             Rainy             Vata           NaN
# 127       Realistic            Winter             Vata           NaN
# 128  Lack of dreams            Summer             Vata           NaN
# 129     Imaginative             Rainy             Vata           NaN
#
# [130 rows x 20 columns]

# %%
df.columns=df.iloc[0]
df=df[1:]

# %%
df['Body Size'].unique()
# Out:
# array(['Slim', 'Medium', 'Large'], dtype=object)

# %%
df=df.drop(['Actual Dosha'],axis=1)

# %%
df
# Out:
# 0   Body Size Body Weight                               Eyes  \
# 1        Slim         Low                              Small
# 2      Medium      Medium                              Sharp
# 3       Large  Overweight                                Big
# 4        Slim      Medium                              Small
# 5      Medium  Overweight                                Big
# ..        ...         ...                                ...
# 125      Slim         Low                 Small, Sunken, Dry
# 126      Slim         Low  Sharp, Bright, Sensitive to Light
# 127      Slim         Low                 Small, Sunken, Dry
# 128      Slim         Low  Sharp, Bright, Sensitive to Light
# 129      Slim         Low                 Small, Sunken, Dry
#
# 0                          Nose           Lips  \
# 1                        Uneven            Dry
# 2                  Long-pointed       Inflamed
# 3                 Short rounded         Smooth
# 4                  Long-pointed       Inflamed
# 5                 Short rounded         Smooth
# ..                          ...            ...
# 125  Long Pointed, Red Nose-Tip  Red, Inflamed
# 126  Short Rounded, Button Nose   Dry, Cracked
# 127  Long Pointed, Red Nose-Tip  Red, Inflamed
# 128  Short Rounded, Button Nose   Dry, Cracked
# 129  Long Pointed, Red Nose-Tip  Red, Inflamed
#
# 0                               Teeth                    Skin  \
# 1                                Thin                     Dry
# 2                              Medium                  Smooth
# 3                             Healthy                    Oily
# 4                              Medium                     Dry
# 5                             Healthy                    Oily
# ..                                ...                     ...
# 125  Stick Out, Big, Roomy, Thin Gums  Thin, Dry, Cold, Rough
# 126         Medium, Soft, Tender Gums      Smooth, Oily, Warm
# 127  Stick Out, Big, Roomy, Thin Gums  Thin, Dry, Cold, Rough
# 128         Medium, Soft, Tender Gums      Smooth, Oily, Warm
# 129  Stick Out, Big, Roomy, Thin Gums  Thin, Dry, Cold, Rough
#
# 0                      Hair            Appetite               Digestion  \
# 1           Dry and brittle           Irregular     Irregular forms gas
# 2         Straight and oily              Strong    Quick causes burning
# 3           Thick and curly     Slow but steady  Prolonged forms mucous
# 4         Straight and oily              Strong    Quick causes burning
# 5           Thick and curly     Slow but steady  Prolonged forms mucous
# ..                      ...                 ...                     ...
# 125        Dry, Brown/Black   Irregular, Scanty      Slow, Forms Mucous
# 126  Straight, Oily, Blonde  Strong, Unbearable   Quick, Causes Burning
# 127        Dry, Brown/Black   Irregular, Scanty      Slow, Forms Mucous
# 128  Straight, Oily, Blonde  Strong, Unbearable   Quick, Causes Burning
# 129        Dry, Brown/Black   Irregular, Scanty      Slow, Forms Mucous
#
# 0        Thirst                         Emotions          Mind  \
# 1    Changeable                          Anxiety      Restless
# 2       Surplus                            Anger     Impatient
# 3        Sparse                             Calm        Calmer
# 4       Surplus                          Anxiety     Impatient
# 5        Sparse                            Anger     Impatient
# ..          ...                              ...           ...
# 125      Sparse            Anger, Hate, Jealousy     Impatient
# 126  Changeable            Anger, Hate, Jealousy  Restlessness
# 127      Sparse  Calmness, Patience, Contentment  Restlessness
# 128  Changeable       Anxiety, Fear, Uncertainty     Impatient
# 129      Sparse  Calmness, Patience, Contentment  Restlessness
#
# 0                    Intellect                     Speech               Voice  \
# 1    Quick but faulty response        Rapid and talkative     Weak and hoarse
# 2            Accurate response            Clear and sharp         Strong tone
# 3               Slow and exact             Quiet and slow  Deep and good tone
# 4            Accurate response        Rapid and talkative     Weak and hoarse
# 5               Slow and exact             Quiet and slow  Deep and good tone
# ..                         ...                        ...                 ...
# 125                Slow, Exact    Clear, Slow, Monotonous     Deep, Good Tone
# 126          Accurate Response  Clear, Sharp, Penetrating         Strong Tone
# 127  Quick but Faulty Response    Quiet, Slow, Monotonous        Weak, Hoarse
# 128  Quick but Faulty Response  Rapid, Unclear, Talkative         Strong Tone
# 129          Accurate Response  Clear, Sharp, Penetrating     Deep, Good Tone
#
# 0            Dreams Season Preferred Predicted Dosha
# 1       Imaginative           Summer            Vata
# 2         Realistic           Winter           Pitta
# 3    Lack of dreams           Summer           Kapha
# 4       Imaginative            Rainy            Vata
# 5    Lack of dreams           Summer           Kapha
# ..              ...              ...             ...
# 125       Realistic           Winter            Vata
# 126  Lack of dreams            Rainy            Vata
# 127       Realistic           Winter            Vata
# 128  Lack of dreams           Summer            Vata
# 129     Imaginative            Rainy            Vata
#
# [129 rows x 19 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for cols in df.columns :
  df[cols]=le.fit_transform(df[cols])

# %%
y=df['Predicted Dosha']
x=df.drop(['Predicted Dosha'],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
#from sklearn.naive_bayes import MultinomialNB

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred1=dt.predict(x_test)

# %%
#mnb=MultinomialNB()

# %%
#mnb.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
#y_pred=mnb.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
#accuracy_score(y_pred,y_test)
# Out:
# 0.6153846153846154

# %%
accuracy_score(y_pred1,y_test)
# Out:
# 0.9743589743589743
